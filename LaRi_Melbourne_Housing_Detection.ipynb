# %% [markdown]
# <a href="https://colab.research.google.com/github/eleven111101/Lasso_Ridge_Regression_01/blob/main/LaRi_Melbourne_Housing_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello_world")
# Out:
# Hello_world

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Melbourne_housing_FULL.csv")

# %%
df.head(10)
# Out:
#        Suburb             Address  Rooms Type      Price Method  SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS   Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB   Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# 5  Abbotsford    40 Federation La      3    h   850000.0     PI   Biggin
# 6  Abbotsford         55a Park St      4    h  1600000.0     VB   Nelson
# 7  Abbotsford        16 Maugie St      4    h        NaN     SN   Nelson
# 8  Abbotsford        53 Turner St      2    h        NaN      S   Biggin
# 9  Abbotsford        99 Turner St      2    h        NaN      S  Collins
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0   3/9/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# ...

# %%
# Check for null values without modifying DataFrame
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
null_values = df[df.isnull()]
print(null_values.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
df["SellerG"].unique()
# Out:
# array(['Jellis', 'Biggin', 'Rounds', 'Nelson', 'Collins', 'Dingle',
#        'Purplebricks', 'Greg', 'Philip', 'LITTLE', 'Kay', 'Beller',
#        'Marshall', 'hockingstuart', 'Brad', 'Maddison', 'Barry',
#        'Airport', 'Considine', 'Rendina', 'Ray', 'Propertyau', 'McDonald',
#        'Frank', 'Prof.', 'Harcourts', 'Thomson', 'Buxton', 'RT',
#        "Sotheby's", 'Cayzer', 'Chisholm', 'McGrath', 'Brace', 'Miles',
#        'Holland', 'Love', 'Thomas', 'Barlow', 'Sweeney', 'Village', 'Jas',
#        'Williams', 'Gunn&Co', 'Burnham', 'Point', 'Compton', 'FN',
#        'Hunter', 'Raine&Horne', 'Noel', 'Hodges', 'Gary', 'Fletchers',
#        'Woodards', 'Raine', 'Alexkarbon', 'Walshe', 'Weda', 'Stockdale',
#        'Tim', 'Buxton/Marshall', 'AIME', 'Moonee', 'HAR', 'Edward', 'RW',
#        'North', 'MICM', 'Ascend', 'Christopher', 'Morrison', 'Bekdon',
#        'Mandy', 'R&H', 'Fletchers/One', 'Lindellas', 'Appleby', 'Assisi',
# ...

# %%
df.shape
# Out:
# (34857, 21)

# %%
df["Bedroom2"].isnull().sum()
# Out:
# 8217

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
# For columns axis=0
df.isnull().sum(axis=0).sort_values(ascending=False)
# Out:
# BuildingArea     21115
# YearBuilt        19306
# Landsize         11810
# Car               8728
# Bathroom          8226
# Bedroom2          8217
# Longtitude        7976
# Lattitude         7976
# Price             7610
# Regionname           3
# CouncilArea          3
# Propertycount        3
# Postcode             1
# Distance             1
# Address              0
# Date                 0
# SellerG              0
# Method               0
# Type                 0
# Rooms                0
# Suburb               0
# dtype: int64

# %%
# For rows axis=1
df.isnull().sum(axis=1).sort_values(ascending=False)
# Out:
# 29483    13
# 18523    11
# 26888    11
# 32125     9
# 11231     9
#          ..
# 24737     0
# 24738     0
# 9437      0
# 9435      0
# 34856     0
# Length: 34857, dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 5      Abbotsford    40 Federation La      3    h   850000.0     PI
# 7      Abbotsford        16 Maugie St      4    h        NaN     SN
# ...           ...                 ...    ...  ...        ...    ...
# 34848     Wollert       16 Gunther Wy      4    h   621000.0      S
# 34850     Wollert    15 Rockgarden Wy      3    h        NaN     SP
# 34851  Yarraville       78 Bayview Rd      3    h  1101000.0      S
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis    3/9/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
df.isnull().sum(axis=0).sort_values(ascending=False) / len(df) *100
# Out:
# BuildingArea     60.576068
# YearBuilt        55.386293
# Landsize         33.881286
# Car              25.039447
# Bathroom         23.599277
# Bedroom2         23.573457
# Longtitude       22.882061
# Lattitude        22.882061
# Price            21.832057
# Regionname        0.008607
# CouncilArea       0.008607
# Propertycount     0.008607
# Postcode          0.002869
# Distance          0.002869
# Address           0.000000
# Date              0.000000
# SellerG           0.000000
# Method            0.000000
# Type              0.000000
# Rooms             0.000000
# Suburb            0.000000
# dtype: float64

# %%
columns_drop=["BuildingArea","YearBuilt"]

# %%
df.drop(columns_drop , axis=1 , inplace=True)

# %%
df.shape
# Out:
# (34857, 19)

# %%
len(df[df.isnull().sum(axis=1) > 5 ]) / len(df) *100
# Out:
# 22.80747052242017

# %%
df[df.isnull().sum(axis=1)  > 5]
# Out:
#              Suburb              Address  Rooms Type      Price Method  \
# 15       Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16       Abbotsford      18a Mollison St      2    t   745000.0      S
# 19       Abbotsford  403/609 Victoria St      2    u   542000.0      S
# 21       Abbotsford    25/84 Trenerry Cr      2    u   760000.0     SP
# 22       Abbotsford    106/119 Turner St      1    u   481000.0     SP
# ...             ...                  ...    ...  ...        ...    ...
# 34838  Williamstown   11/81 Melbourne Rd      2    u   450000.0     SP
# 34839  Williamstown     24/18 Station Rd      2    u   475000.0     SP
# 34840  Williamstown      3/2 Thompson St      2    u   520000.0     VB
# 34844       Windsor     4/16 Lewisham Rd      1    u   440000.0     SP
# 34855    Yarraville     12/37 Stephen St      3    h  1140000.0     SP
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df[df.isnull().sum(axis=1)  <= 5]
# Out:
#            Suburb             Address  Rooms Type      Price Method  SellerG  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS   Jellis
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB   Rounds
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# ...           ...                 ...    ...  ...        ...    ...      ...
# 34851  Yarraville       78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville      147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
df=df[df.isnull().sum(axis=1)  <= 5]

# %%
df.shape
# Out:
# (26907, 19)

# %%
df.isnull().sum(axis=0).sort_values(ascending=False)/len(df)*100
# Out:
# Price            21.897647
# Landsize         14.345709
# Car               2.891441
# Bathroom          1.025755
# Bedroom2          0.992307
# Longtitude        0.096629
# Lattitude         0.096629
# Suburb            0.000000
# Regionname        0.000000
# CouncilArea       0.000000
# Postcode          0.000000
# Address           0.000000
# Distance          0.000000
# Date              0.000000
# SellerG           0.000000
# Method            0.000000
# Type              0.000000
# Rooms             0.000000
# Propertycount     0.000000
# dtype: float64

# %%
df = df[df["Price"].notnull()]

# %%
df.isnull().sum(axis=0).sort_values(ascending=False)/len(df)*100
# Out:
# Landsize         14.432548
# Car               2.817035
# Bathroom          1.023079
# Bedroom2          0.994528
# Longtitude        0.104687
# Lattitude         0.104687
# Suburb            0.000000
# Regionname        0.000000
# CouncilArea       0.000000
# Postcode          0.000000
# Address           0.000000
# Distance          0.000000
# Date              0.000000
# SellerG           0.000000
# Method            0.000000
# Price             0.000000
# Type              0.000000
# Rooms             0.000000
# Propertycount     0.000000
# dtype: float64

# %%
df = df[df["Landsize"].notnull()]

# %%
df["Landsize"].describe()
# Out:
# count     17982.000000
# mean        593.488933
# std        3757.266429
# min           0.000000
# 25%         219.000000
# 50%         512.000000
# 75%         664.000000
# max      433014.000000
# Name: Landsize, dtype: float64

# %%
df = df[df["Landsize"].notnull()]

# %%
df.isnull().sum(axis=0).sort_values(ascending=False)/len(df)*100
# Out:
# Car              1.562674
# Longtitude       0.122345
# Lattitude        0.122345
# Bathroom         0.050050
# Bedroom2         0.033367
# Suburb           0.000000
# Regionname       0.000000
# CouncilArea      0.000000
# Landsize         0.000000
# Postcode         0.000000
# Address          0.000000
# Distance         0.000000
# Date             0.000000
# SellerG          0.000000
# Method           0.000000
# Price            0.000000
# Type             0.000000
# Rooms            0.000000
# Propertycount    0.000000
# dtype: float64

# %%
df = df[df["Longtitude"].notnull()]
df = df[df["Lattitude"].notnull()]

# %%
df.isnull().sum(axis=0).sort_values(ascending=False)/len(df)*100
# Out:
# Car              1.564588
# Bathroom         0.050111
# Bedroom2         0.033408
# Suburb           0.000000
# Regionname       0.000000
# Longtitude       0.000000
# Lattitude        0.000000
# CouncilArea      0.000000
# Landsize         0.000000
# Postcode         0.000000
# Address          0.000000
# Distance         0.000000
# Date             0.000000
# SellerG          0.000000
# Method           0.000000
# Price            0.000000
# Type             0.000000
# Rooms            0.000000
# Propertycount    0.000000
# dtype: float64

# %%
df["Car"].describe()
# Out:
# count    17679.000000
# mean         1.698739
# std          0.999023
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max         18.000000
# Name: Car, dtype: float64

# %%
df["Car"].astype("category").value_counts()
# Out:
# Car
# 2.0     7955
# 1.0     6477
# 0.0     1178
# 3.0     1065
# 4.0      777
# 5.0       99
# 6.0       92
# 7.0       16
# 8.0       12
# 10.0       4
# 9.0        2
# 11.0       1
# 18.0       1
# Name: count, dtype: int64

# %%
df["Car"].value_counts()
# Out:
# Car
# 2.0     7955
# 1.0     6477
# 0.0     1178
# 3.0     1065
# 4.0      777
# 5.0       99
# 6.0       92
# 7.0       16
# 8.0       12
# 10.0       4
# 9.0        2
# 18.0       1
# 11.0       1
# Name: count, dtype: int64

# %%
df["Car"]
# Out:
# 1        1.0
# 2        0.0
# 4        0.0
# 5        1.0
# 6        2.0
#         ...
# 34851    NaN
# 34852    3.0
# 34853    1.0
# 34854    2.0
# 34856    0.0
# Name: Car, Length: 17960, dtype: float64

# %%
df["Car"].fillna(0 , inplace = True)

# %%
df.isnull().sum(axis=0).sort_values(ascending=False)/len(df)*100
# Out:
# Bathroom         0.050111
# Bedroom2         0.033408
# Suburb           0.000000
# Regionname       0.000000
# Longtitude       0.000000
# Lattitude        0.000000
# CouncilArea      0.000000
# Landsize         0.000000
# Car              0.000000
# Postcode         0.000000
# Address          0.000000
# Distance         0.000000
# Date             0.000000
# SellerG          0.000000
# Method           0.000000
# Price            0.000000
# Type             0.000000
# Rooms            0.000000
# Propertycount    0.000000
# dtype: float64

# %%
df["Bathroom"].value_counts()
# Out:
# Bathroom
# 1.0    9270
# 2.0    7132
# 3.0    1304
# 4.0     154
# 5.0      43
# 0.0      34
# 6.0       9
# 7.0       2
# 8.0       2
# 9.0       1
# Name: count, dtype: int64

# %%
df["Bathroom"].fillna(1,inplace=True)

# %%
df["Bedroom2"].value_counts()
# Out:
# Bedroom2
# 3.0     8094
# 2.0     4127
# 4.0     4055
# 5.0      840
# 1.0      701
# 6.0       91
# 0.0       16
# 7.0       14
# 8.0        7
# 10.0       4
# 9.0        3
# 20.0       1
# 12.0       1
# Name: count, dtype: int64

# %%
df["Bedroom2"].fillna(3,inplace=True)

# %%
df.isnull().sum(axis=0).sort_values(ascending=False)/len(df)*100
# Out:
# Suburb           0.0
# Bedroom2         0.0
# Regionname       0.0
# Longtitude       0.0
# Lattitude        0.0
# CouncilArea      0.0
# Landsize         0.0
# Car              0.0
# Bathroom         0.0
# Postcode         0.0
# Address          0.0
# Distance         0.0
# Date             0.0
# SellerG          0.0
# Method           0.0
# Price            0.0
# Type             0.0
# Rooms            0.0
# Propertycount    0.0
# dtype: float64

# %%
print("I love python")
# Out:
# I love python

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17960 entries, 1 to 34856
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         17960 non-null  object
#  1   Address        17960 non-null  object
#  2   Rooms          17960 non-null  int64
#  3   Type           17960 non-null  object
#  4   Price          17960 non-null  float64
#  5   Method         17960 non-null  object
#  6   SellerG        17960 non-null  object
#  7   Date           17960 non-null  object
#  8   Distance       17960 non-null  float64
#  9   Postcode       17960 non-null  float64
#  10  Bedroom2       17960 non-null  float64
#  11  Bathroom       17960 non-null  float64
#  12  Car            17960 non-null  float64
#  13  Landsize       17960 non-null  float64
#  14  CouncilArea    17960 non-null  object
#  15  Lattitude      17960 non-null  float64
#  16  Longtitude     17960 non-null  float64
# ...

# %%
df["Date"]
# Out:
# 1         3/12/2016
# 2          4/2/2016
# 4          4/3/2017
# 5          4/3/2017
# 6          4/6/2016
#             ...
# 34851    24/02/2018
# 34852    24/02/2018
# 34853    24/02/2018
# 34854    24/02/2018
# 34856    24/02/2018
# Name: Date, Length: 17960, dtype: object

# %%
df["Date"]=pd.to_datetime(df["Date"], format="%d/%m/%Y")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17960 entries, 1 to 34856
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         17960 non-null  object
#  1   Address        17960 non-null  object
#  2   Rooms          17960 non-null  int64
#  3   Type           17960 non-null  object
#  4   Price          17960 non-null  float64
#  5   Method         17960 non-null  object
#  6   SellerG        17960 non-null  object
#  7   Date           17960 non-null  datetime64[ns]
#  8   Distance       17960 non-null  float64
#  9   Postcode       17960 non-null  float64
#  10  Bedroom2       17960 non-null  float64
#  11  Bathroom       17960 non-null  float64
#  12  Car            17960 non-null  float64
#  13  Landsize       17960 non-null  float64
#  14  CouncilArea    17960 non-null  object
#  15  Lattitude      17960 non-null  float64
#  16  Longtitude     17960 non-null  float64
# ...

# %%
df["Date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 17960 entries, 1 to 34856
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 17960 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 280.6 KB

# %%
df["Date"]
# Out:
# 1       2016-12-03
# 2       2016-02-04
# 4       2017-03-04
# 5       2017-03-04
# 6       2016-06-04
#            ...
# 34851   2018-02-24
# 34852   2018-02-24
# 34853   2018-02-24
# 34854   2018-02-24
# 34856   2018-02-24
# Name: Date, Length: 17960, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17960 entries, 1 to 34856
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         17960 non-null  object
#  1   Address        17960 non-null  object
#  2   Rooms          17960 non-null  int64
#  3   Type           17960 non-null  object
#  4   Price          17960 non-null  float64
#  5   Method         17960 non-null  object
#  6   SellerG        17960 non-null  object
#  7   Date           17960 non-null  datetime64[ns]
#  8   Distance       17960 non-null  float64
#  9   Postcode       17960 non-null  float64
#  10  Bedroom2       17960 non-null  float64
#  11  Bathroom       17960 non-null  float64
#  12  Car            17960 non-null  float64
#  13  Landsize       17960 non-null  float64
#  14  CouncilArea    17960 non-null  object
#  15  Lattitude      17960 non-null  float64
#  16  Longtitude     17960 non-null  float64
# ...

# %%
pd.to_datetime(df["Date"])
# Out:
# 1       2016-12-03
# 2       2016-02-04
# 4       2017-03-04
# 5       2017-03-04
# 6       2016-06-04
#            ...
# 34851   2018-02-24
# 34852   2018-02-24
# 34853   2018-02-24
# 34854   2018-02-24
# 34856   2018-02-24
# Name: Date, Length: 17960, dtype: datetime64[ns]

# %%
df["Date"][1]
# Out:
# Timestamp('2016-12-03 00:00:00')

# %%
df["Date"][1].year
# Out:
# 2016

# %%
df["Date"][1].month
# Out:
# 12

# %%
df["Date"][1].day
# Out:
# 3

# %%
df["Year"]=df["Date"].apply(lambda x : x.year)

# %%
df["Month"]=df["Date"].apply(lambda x : x.month)

# %%
df=df.drop("Date",axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17960 entries, 1 to 34856
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         17960 non-null  object
#  1   Address        17960 non-null  object
#  2   Rooms          17960 non-null  int64
#  3   Type           17960 non-null  object
#  4   Price          17960 non-null  float64
#  5   Method         17960 non-null  object
#  6   SellerG        17960 non-null  object
#  7   Distance       17960 non-null  float64
#  8   Postcode       17960 non-null  float64
#  9   Bedroom2       17960 non-null  float64
#  10  Bathroom       17960 non-null  float64
#  11  Car            17960 non-null  float64
#  12  Landsize       17960 non-null  float64
#  13  CouncilArea    17960 non-null  object
#  14  Lattitude      17960 non-null  float64
#  15  Longtitude     17960 non-null  float64
#  16  Regionname     17960 non-null  object
# ...

# %%
for cols in df.columns:
  print(cols,":",len(df[cols].unique()))
# Out:
# Suburb : 333
# Address : 17643
# Rooms : 10
# Type : 3
# Price : 2457
# Method : 5
# SellerG : 309
# Distance : 207
# Postcode : 204
# Bedroom2 : 13
# Bathroom : 10
# Car : 13
# Landsize : 1556
# CouncilArea : 33
# Lattitude : 9548
# Longtitude : 10292
# Regionname : 8
# Propertycount : 328
# Year : 3
# Month : 12

# %%
columns_for_dummy={
    "Suburb":"SU",
    "Type":"TY",
    "Method":"ME",
    "SellerG":"SE",
    "CouncilArea":"CO",
    "Regionname":"RE"
}

# %%
print(columns_for_dummy["CouncilArea"])
# Out:
# CO

# %%
for key, value in columns_for_dummy.items():
  print(key , value)
# Out:
# Suburb SU
# Type TY
# Method ME
# SellerG SE
# CouncilArea CO
# Regionname RE

# %%
for key, value in columns_for_dummy.items():
  dummies=pd.get_dummies(df[key], prefix=value, drop_first=True)
  df=pd.concat([df,dummies], axis=1)
  df=df.drop(key, axis=1)

# %%
df.head()
# Out:
#             Address  Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  \
# 1      85 Turner St      2  1480000.0       2.5    3067.0       2.0       1.0
# 2   25 Bloomburg St      2  1035000.0       2.5    3067.0       2.0       1.0
# 4      5 Charles St      3  1465000.0       2.5    3067.0       3.0       2.0
# 5  40 Federation La      3   850000.0       2.5    3067.0       3.0       2.0
# 6       55a Park St      4  1600000.0       2.5    3067.0       3.0       1.0
#
#    Car  Landsize  Lattitude  ...  CO_Wyndham City Council  \
# 1  1.0     202.0   -37.7996  ...                    False
# 2  0.0     156.0   -37.8079  ...                    False
# 4  0.0     134.0   -37.8093  ...                    False
# 5  1.0      94.0   -37.7969  ...                    False
# 6  2.0     120.0   -37.8072  ...                    False
#
#    CO_Yarra City Council  CO_Yarra Ranges Shire Council  RE_Eastern Victoria  \
# ...

# %%
df.drop(["Address","Postcode","Propertycount"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Rooms      Price  Distance  Bedroom2  Bathroom  Car  Landsize  Lattitude  \
# 1      2  1480000.0       2.5       2.0       1.0  1.0     202.0   -37.7996
# 2      2  1035000.0       2.5       2.0       1.0  0.0     156.0   -37.8079
# 4      3  1465000.0       2.5       3.0       2.0  0.0     134.0   -37.8093
# 5      3   850000.0       2.5       3.0       2.0  1.0      94.0   -37.7969
# 6      4  1600000.0       2.5       3.0       1.0  2.0     120.0   -37.8072
#
#    Longtitude  Year  ...  CO_Wyndham City Council  CO_Yarra City Council  \
# 1    144.9984  2016  ...                    False                   True
# 2    144.9934  2016  ...                    False                   True
# 4    144.9944  2017  ...                    False                   True
# 5    144.9969  2017  ...                    False                   True
# 6    144.9941  2016  ...                    False                   True
#
#    CO_Yarra Ranges Shire Council  RE_Eastern Victoria  \
# ...

# %%
df.shape
# Out:
# (17960, 696)

# %%
X=df.drop("Price",axis=1)
y=df["Price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression , Ridge , Lasso

# %%
li =LinearRegression()
li.fit(X_train,y_train)
li_predict = li.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score

# %%
print("...Linear_Regression...")
print("Mean_absolute_error - ",mean_absolute_error(y_test , li_predict))
print("Mean_squared_error - ",mean_squared_error(y_test , li_predict))
print("Root_Mean_absolute_error - ",np.sqrt(mean_squared_error(y_test , li_predict)))
print("R2_Score - ",r2_score(y_test , li_predict))
# Out:
# Mean_absolute_error -  237375.61678513503
# Mean_squared_error -  137859624244.53598
# Root_Mean_absolute_error -  371294.524932076
# R2_Score -  0.682554621750407

# %%
la = Lasso(alpha=50,tol=0.1,max_iter=1000)
la.fit(X_train,y_train)
la_predict = la.predict(X_test)

# %%
print("...Lasso_Regression...")
print("Mean_absolute_error - ",mean_absolute_error(y_test , la_predict))
print("Mean_squared_error - ",mean_squared_error(y_test , la_predict))
print("Root_Mean_absolute_error - ",np.sqrt(mean_squared_error(y_test , la_predict)))
print("R2_Score - ",r2_score(y_test , la_predict))
# Out:
# ...Lasso_Regression...
# Mean_absolute_error -  234086.4182392438
# Mean_squared_error -  132776871920.99223
# Root_Mean_absolute_error -  364385.6088280549
# R2_Score -  0.6942585288424089

# %%
ri = Ridge(alpha=4)
ri.fit(X_train,y_train)
ri_predict = ri.predict(X_test)

# %%
print("...Ridge_Regression...")
print("Mean_absolute_error - ",mean_absolute_error(y_test , ri_predict))
print("Mean_squared_error - ",mean_squared_error(y_test , ri_predict))
print("Root_Mean_absolute_error - ",np.sqrt(mean_squared_error(y_test , ri_predict)))
print("R2_Score - ",r2_score(y_test , ri_predict))
# Out:
# ...Ridge_Regression...
# Mean_absolute_error -  234018.94993403254
# Mean_squared_error -  132586659852.82622
# Root_Mean_absolute_error -  364124.5114693959
# R2_Score -  0.6946965246824346
